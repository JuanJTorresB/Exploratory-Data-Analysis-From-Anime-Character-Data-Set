# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

content = pd.read_csv('anime_characters.csv')

# %%
content.info()
content.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37580 entries, 0 to 37579
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   mal_id                37580 non-null  int64
#  1   url                   37580 non-null  object
#  2   name                  37580 non-null  object
#  3   name_kanji            27835 non-null  object
#  4   nicknames             5595 non-null   object
#  5   favorites             37580 non-null  int64
#  6   about                 21519 non-null  object
#  7   image_jpg_url         37580 non-null  object
#  8   image_webp_url        37580 non-null  object
#  9   image_webp_small_url  37579 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 2.9+ MB
#                mal_id                                               url  \
# count    37580.000000                                             37580
# unique            NaN                                             37529
# top               NaN  https://myanimelist.net/character/220106/Nadrika
# freq              NaN                                                 4
# mean    147010.001836                                               NaN
# std      85399.147346                                               NaN
# min          1.000000                                               NaN
# 25%      69888.500000                                               NaN
# 50%     178060.000000                                               NaN
# 75%     223144.250000                                               NaN
# max     264246.000000                                               NaN
#
#             name name_kanji nicknames      favorites  \
# count      37580      27835      5595   37580.000000
# unique     32938      25638      5152            NaN
# top     Narrator     ナレーション  Princess            NaN
# freq          97         27        15            NaN
# mean         NaN        NaN       NaN      75.307877
# std          NaN        NaN       NaN    1688.473497
# min          NaN        NaN       NaN       0.000000
# 25%          NaN        NaN       NaN       0.000000
# 50%          NaN        NaN       NaN       0.000000
# 75%          NaN        NaN       NaN       2.000000
# max          NaN        NaN       NaN  144778.000000
#
#                                                     about  \
# count                                               21519
# unique                                              20804
# top     No voice actors have been added to this charac...
# freq                                                   28
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             image_jpg_url  \
# count                                               37580
# unique                                              33195
# top     https://cdn.myanimelist.net/img/sp/icon/apple-...
# freq                                                 4338
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            image_webp_url  \
# count                                               37580
# unique                                              33195
# top     https://cdn.myanimelist.net/img/sp/icon/apple-...
# freq                                                 4338
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                      image_webp_small_url
# count                                               37579
# unique                                              33194
# top     https://cdn.myanimelist.net/img/sp/icon/apple-...
# freq                                                 4338
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
content.head()
# Out:
#    mal_id                                                url             name  \
# 0       1  https://myanimelist.net/character/1/Spike_Spiegel    Spike Spiegel
# 1       2  https://myanimelist.net/character/2/Faye_Valen...   Faye Valentine
# 2       3      https://myanimelist.net/character/3/Jet_Black        Jet Black
# 3       4            https://myanimelist.net/character/4/Ein              Ein
# 4       5  https://myanimelist.net/character/5/Ichigo_Kur...  Ichigo Kurosaki
#
#    name_kanji                                          nicknames  favorites  \
# 0  スパイク・スピーゲル                                                NaN      48133
# 1  フェイ・バレンタイン                                                NaN       9474
# 2   ジェット・ブラック                            Running Rock, Black Dog       2239
# 3         アイン                                                NaN       2378
# 4       黒崎 一護  Ichi-nii, Shinigami Daiko (Substitute Soul Rea...      35561
#
#                                                about  \
# 0  Birthdate: June 26, 2044 Height: 185 cm (6' 1"...
# 1  Birthday: August 14, 1994  One of the members ...
# 2  Jet, known on his home satellite as the "Black...
# 3  Ein is a Pembroke Welsh Corgi brought aboard t...
# 4  Race: Human Birthday: July 15 (Cancer) Age: 15...
#
#                                        image_jpg_url  \
# 0  https://cdn.myanimelist.net/images/characters/...
# 1  https://cdn.myanimelist.net/images/characters/...
# 2  https://cdn.myanimelist.net/images/characters/...
# 3  https://cdn.myanimelist.net/images/characters/...
# 4  https://cdn.myanimelist.net/images/characters/...
#
#                                       image_webp_url  \
# 0  https://cdn.myanimelist.net/images/characters/...
# 1  https://cdn.myanimelist.net/images/characters/...
# 2  https://cdn.myanimelist.net/images/characters/...
# 3  https://cdn.myanimelist.net/images/characters/...
# 4  https://cdn.myanimelist.net/images/characters/...
#
#                                 image_webp_small_url
# 0  https://cdn.myanimelist.net/images/characters/...
# 1  https://cdn.myanimelist.net/images/characters/...
# 2  https://cdn.myanimelist.net/images/characters/...
# 3  https://cdn.myanimelist.net/images/characters/...
# 4  https://cdn.myanimelist.net/images/characters/...

# %%
(content.isnull().sum() / content.shape[0]) * 100
# Out:
# mal_id                   0.000000
# url                      0.000000
# name                     0.000000
# name_kanji              25.931346
# nicknames               85.111762
# favorites                0.000000
# about                   42.738159
# image_jpg_url            0.000000
# image_webp_url           0.000000
# image_webp_small_url     0.002661
# dtype: float64

# %%
content.nunique()
# Out:
# mal_id                  37529
# url                     37529
# name                    32938
# name_kanji              25638
# nicknames                5152
# favorites                 855
# about                   20804
# image_jpg_url           33195
# image_webp_url          33195
# image_webp_small_url    33194
# dtype: int64

# %%
favorites = content['favorites']

print("Favorites - Basic Stats")
print(f"Min: {favorites.min()}")
print(f"Max: {favorites.max()}")
print(f"Mean: {favorites.mean():.2f}")
print(f"Median: {favorites.median()}")
print(f"Standard Deviation: {favorites.std():.2f}")
print(f"25th Percentile: {favorites.quantile(0.25)}")
print(f"75th Percentile: {favorites.quantile(0.75)}")

# How many characters have 0 favorites?
print(f"Characters with 0 favorites: {(favorites == 0).sum()} ({(favorites == 0).mean()*100:.2f}%)")

# Characters with >1000 favorites
print(f"Characters with >1000 favorites: {(favorites > 1000).sum()}")
# Out:
# Favorites - Basic Stats
# Min: 0
# Max: 144778
# Mean: 75.31
# Median: 0.0
# Standard Deviation: 1688.47
# 25th Percentile: 0.0
# 75th Percentile: 2.0
# Characters with 0 favorites: 22997 (61.19%)
# Characters with >1000 favorites: 318

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=favorites[favorites < 1000])  # Limiting outliers for better scale
plt.title("Boxplot of Character Favorites (limited to < 1000)")
plt.show()
